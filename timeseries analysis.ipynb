# %%
1+6
# Out:
# 7

# %%
21*4
# Out:
# 84

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
raw = pd.read_csv("/home/solo/Desktop/Index2018.csv")
raw.head()
raw.describe()
raw.isnull().sum()
raw.isna()
raw.spx.isna().sum()

#plotting the data
raw.spx.plot(figsize=(20,10), title = "S&P500 Prices")
# Out:
# <Axes: title={'center': 'S&P500 Prices'}>
